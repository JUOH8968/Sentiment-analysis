# %% [markdown]
# # 미니프로젝트_감정분석

# %% [markdown]
# ## 1. 웹 리뷰크롤링

# %%
pip install google_play_scraper
# Out:
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.2 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.7

# %%
pip install tika
# Out:
# Collecting tika
#   Downloading tika-3.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tika) (75.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tika) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tika) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->tika) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tika) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->tika) (2025.8.3)
# Downloading tika-3.1.0-py3-none-any.whl (38 kB)
# Installing collected packages: tika
# Successfully installed tika-3.1.0

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from konlpy) (5.4.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.12/dist-packages (from konlpy) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from JPype1>=0.7.0->konlpy) (25.0)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 92.8 MB/s eta 0:00:00
# Downloading jpype1-1.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (495 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.9/495.9 kB 32.3 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.6.0 konlpy-0.6.0

# %%
## google_play_scraper 에 속해있는 함수확인하기
import google_play_scraper
dir(google_play_scraper)
# Out:
# ['Device',
#  'Sort',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'app',
#  'constants',
#  'exceptions',
#  'features',
#  'permissions',
#  'reviews',
#  'reviews_all',
#  'search',
#  'utils']

# %%
#  함수가 필요로 하는 인자값 확인
help(reviews_all)
# Out:
# Help on function reviews_all in module google_play_scraper.features.reviews:
#
# reviews_all(app_id: str, sleep_milliseconds: int = 0, **kwargs) -> list

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, Sort, reviews_all

url = "com.fineapp.yogiyo"
# com.coupang.mobile.eats-> 쿠팡이츠
# com.sampleapp -> 배달의 민족
# com.fineapp.yogiyo --> 요기요

# 앱 정보 크롤링
app = app(url,lang = "ko", #언어 한국어
                country = "kr") #나라 한국으로 설정

# 앱 리뷰 크롤링
review = reviews_all(url,
                    sleep_milliseconds = 500, # 0.5초 대기시간
                    lang = "ko",# default = "en"
                    country = "kr", # default = "US"
                    sort = Sort.MOST_RELEVANT, # Sort.NEWEST , 관련성 높은순으로 정렬
                    filter_score_with = None # None means All score
                    )
# 데이터프레임 변환
df_yo= pd.DataFrame(review)
df_yo.head(2)
# Out:
#                                reviewId    userName  \
# 0  0ced25ca-88a0-498c-8f04-ffdb70f7672a  Google 사용자
# 1  e0e13af8-26ad-44b4-9339-5210779cf081  Google 사용자
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  제가 이 앱을 요기패스까지 했을 정도로 잘 쓰다가 ㅂㅁ으로 갈아탔는데요 그 이유가 ...      3              2
# 1  현재 가게마다 음식 메뉴를 눌렀을 때, 맨 하단에 있는 (수량 및 담기) UI 버튼...      5            180
#
#   reviewCreatedVersion                  at  \
# 0               8.53.0 2025-08-18 18:23:16
# 1               8.54.0 2025-08-27 06:03:06
#
#                                         replyContent           repliedAt  \
# 0  안녕하세요, 고객님. 요기요입니다.\n이용에 불편을 드렸다면 죄송합니다.\n남겨수진... 2025-08-20 03:48:33
# 1  안녕하세요, 고객님. 요기요입니다.\n사용에 불편을 드려 죄송합니다. 말씀하신 부분... 2025-08-27 08:25:47
#
#   appVersion
# 0     8.53.0
# 1     8.54.0

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, Sort, reviews_all

url = "com.coupang.mobile.eats"
# com.coupang.mobile.eats-> 쿠팡이츠
# com.sampleapp -> 배달의 민족
# com.fineapp.yogiyo --> 요기요

# 앱 정보 크롤링
app = app(url,lang = "ko", #언어 한국어
                country = "kr") #나라 한국으로 설정

# 앱 리뷰 크롤링
review = reviews_all(url,
                    sleep_milliseconds = 500, # 0.5초 대기시간
                    lang = "ko",# default = "en"
                    country = "kr", # default = "US"
                    sort = Sort.MOST_RELEVANT, # Sort.NEWEST , 관련성 높은순으로 정렬
                    filter_score_with = None # None means All score
                    )
# 데이터프레임 변환
df_co = pd.DataFrame(review)
df_co.head(2)
# Out:
#                                reviewId    userName  \
# 0  d42b09a3-d576-4d00-91ef-8c19761b0c63  Google 사용자
# 1  af6d216a-c5c9-4c4e-8c71-200b86da6f04  Google 사용자
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  배민만 쓰다가 이번에 와우 결제해서 1만원 쿠폰 줬길래 처음 썼는데 진짜 불편함. ...      1             36
# 1  앱자체의 내비게이션이 말도 못하게 불편하다. 정북방향고정도 안되고 주행방향 화살표 ...      1             10
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0               1.5.38 2025-08-03 04:15:04         None       NaT     1.5.38
# 1               1.5.39 2025-08-09 07:12:56         None       NaT     1.5.39

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, Sort, reviews_all

url = "com.coupang.mobile.eats"

# 앱 정보 크롤링
app = app(url,lang = "ko", #언어 한국어
                country = "kr") #나라 한국으로 설정

# 앱 리뷰 크롤링
review = reviews_all(url,
                    sleep_milliseconds = 500, # 0.5초 대기시간
                    lang = "ko",# default = "en"
                    country = "kr", # default = "US"
                    sort = Sort.MOST_RELEVANT, # Sort.NEWEST , 관련성 높은순으로 정렬
                    filter_score_with = None # None means All score
                    )
# 데이터프레임 변환
df_review = pd.DataFrame(review)
df_review.head(2)
# Out:
#                                reviewId    userName  \
# 0  d42b09a3-d576-4d00-91ef-8c19761b0c63  Google 사용자
# 1  af6d216a-c5c9-4c4e-8c71-200b86da6f04  Google 사용자
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  배민만 쓰다가 이번에 와우 결제해서 1만원 쿠폰 줬길래 처음 썼는데 진짜 불편함. ...      1             36
# 1  앱자체의 내비게이션이 말도 못하게 불편하다. 정북방향고정도 안되고 주행방향 화살표 ...      1             10
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0               1.5.38 2025-08-03 04:15:04         None       NaT     1.5.38
# 1               1.5.39 2025-08-09 07:12:56         None       NaT     1.5.39

# %%
df= pd.concat([df_co,df_yo])
df
# Out:
#                                     reviewId    userName  \
# 0       d42b09a3-d576-4d00-91ef-8c19761b0c63  Google 사용자
# 1       af6d216a-c5c9-4c4e-8c71-200b86da6f04  Google 사용자
# 2       443e7afe-4df6-430e-a29b-cc456aec3f9a  Google 사용자
# 3       e69b8533-bf18-4f4c-800d-0666f75d5d8a  Google 사용자
# 4       d2437c5d-e99b-4803-8aff-156595d2a370  Google 사용자
# ...                                      ...         ...
# 138274  d58dbacc-5053-4dc8-90b9-0d56baee44a7  Google 사용자
# 138275  d3b27e63-bd6a-4e6a-a77b-0e0f8692816e  Google 사용자
# 138276  ac8ce23d-e4da-41df-abce-4900b6b023ed  Google 사용자
# 138277  a6f9ad39-308f-46e2-88d6-62b1d94602d5  Google 사용자
# 138278  4b4d55ba-6ea8-4134-9266-277a3d3b0bff  Google 사용자
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/EGemoI2N...
# 1       https://play-lh.googleusercontent.com/EGemoI2N...
# 2       https://play-lh.googleusercontent.com/EGemoI2N...
# 3       https://play-lh.googleusercontent.com/EGemoI2N...
# 4       https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                   ...
# 138274  https://play-lh.googleusercontent.com/EGemoI2N...
# 138275  https://play-lh.googleusercontent.com/EGemoI2N...
# 138276  https://play-lh.googleusercontent.com/EGemoI2N...
# 138277  https://play-lh.googleusercontent.com/EGemoI2N...
# 138278  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0       배민만 쓰다가 이번에 와우 결제해서 1만원 쿠폰 줬길래 처음 썼는데 진짜 불편함. ...      1
# 1       앱자체의 내비게이션이 말도 못하게 불편하다. 정북방향고정도 안되고 주행방향 화살표 ...      1
# 2       1. 배민처럼 한 그릇 배달이 나온 건 좋은데, 클릭하기 전에는 저렴한 가격으로 적...      2
# 3       하... 기분좋게 밥먹을려고했는데 진짜 너무 아쉽고 도착했다는 알람음에 기분좋게나갔...      1
# 4       1. 건의사항을 남기려고 보니 1:1실시간채팅/메일/전화상담뿐이더라고요. 따로 건의...      5
# ...                                                   ...    ...
# 138274                                               None      3
# 138275                                               None      1
# 138276                                               None      1
# 138277                                               None      1
# 138278                                               None      1
#
#         thumbsUpCount reviewCreatedVersion                  at  \
# 0                  36               1.5.38 2025-08-03 04:15:04
# 1                  10               1.5.39 2025-08-09 07:12:56
# 2                   9               1.5.39 2025-08-11 09:43:05
# 3                   6               1.5.39 2025-08-10 15:29:07
# 4                  35               1.5.40 2025-08-19 09:34:00
# ...               ...                  ...                 ...
# 138274              0                 None 2015-01-13 07:47:01
# 138275              0                 None 2014-03-15 08:07:49
# 138276              0                 None 2014-02-26 15:03:38
# 138277              0                 None 2014-03-12 22:15:31
# 138278              0                 None 2014-03-07 10:15:57
#
#                                              replyContent           repliedAt  \
# 0                                                    None                 NaT
# 1                                                    None                 NaT
# 2                                                    None                 NaT
# 3                                                    None                 NaT
# 4       안녕하세요, 쿠팡이츠 입니다.\n\n먼저 쿠팡이츠 APP을 이용하시는 과정에 불편을... 2025-03-19 07:27:37
# ...                                                   ...                 ...
# 138274  안녕하세요, 생활을 바꾸는 주문 요기요입니다. 요기요 앱 다운로드 후 이용의견 남겨... 2015-01-13 23:29:22
# 138275                                               None                 NaT
# 138276                                               None                 NaT
# 138277                                               None                 NaT
# 138278                                               None                 NaT
#
#        appVersion
# 0          1.5.38
# 1          1.5.39
# 2          1.5.39
# 3          1.5.39
# 4          1.5.40
# ...           ...
# 138274       None
# 138275       None
# 138276       None
# 138277       None
# 138278       None
#
# [198495 rows x 11 columns]

# %%
df = df[['content','score']]
# df=DataFrame(df_review,columns=['content','score']) #위에 데이터프레임에서 content와 score 만 추출
df
# Out:
#                                                   content  score
# 0       배민만 쓰다가 이번에 와우 결제해서 1만원 쿠폰 줬길래 처음 썼는데 진짜 불편함. ...      1
# 1       앱자체의 내비게이션이 말도 못하게 불편하다. 정북방향고정도 안되고 주행방향 화살표 ...      1
# 2       1. 배민처럼 한 그릇 배달이 나온 건 좋은데, 클릭하기 전에는 저렴한 가격으로 적...      2
# 3       하... 기분좋게 밥먹을려고했는데 진짜 너무 아쉽고 도착했다는 알람음에 기분좋게나갔...      1
# 4       1. 건의사항을 남기려고 보니 1:1실시간채팅/메일/전화상담뿐이더라고요. 따로 건의...      5
# ...                                                   ...    ...
# 138274                                               None      3
# 138275                                               None      1
# 138276                                               None      1
# 138277                                               None      1
# 138278                                               None      1
#
# [198495 rows x 2 columns]

# %%
df.sort_values(['score'], ascending=[False]) #내림차순으로 정렬
# Out:
#                                                   content  score
# 138272                                               None      5
# 138256                                                  👍      5
# 138255                                                  😀      5
# 138254                                                  👍      5
# 138253                                                  👍      5
# ...                                                   ...    ...
# 39961                                           배달비 너무 비쌈      1
# 39962       지들맘대로 포인트없애고 모르쇠하고 업체도 관리안하고 소비자는 그냥 봉으로 아는기업      1
# 13      배달 시키면 딸배들이 자꾸 이상한곳으로 배달을 감 정신머리가 없는건지 수준이 알만함...      1
# 6       제가 진짜 이해가 하나도 안돼서 그런데 주문할때마다 현금이랑 신용카드 위치를 바꾸자...      1
# 5       주문자가 제대로 된 주소 써도 주소 표시도 똑바로 안 떠서 매번 밥이 다른 곳으로 ...      1
#
# [138279 rows x 2 columns]

# %%
worst= df[:][df['score']==1] # score 값이 1점인 리뷰만 추출
worst
# Out:
#                                                   content  score
# 0       배민만 쓰다가 이번에 와우 결제해서 1만원 쿠폰 줬길래 처음 썼는데 진짜 불편함. ...      1
# 1       앱자체의 내비게이션이 말도 못하게 불편하다. 정북방향고정도 안되고 주행방향 화살표 ...      1
# 3       하... 기분좋게 밥먹을려고했는데 진짜 너무 아쉽고 도착했다는 알람음에 기분좋게나갔...      1
# 6       배달현황 알림 말고 다른 알림을 끄는 기능이 없음. 음식 맛있었냐는 알림은 배달현황...      1
# 10      카드 일반결제를 쓰는데 네이버페이나 삼성페이로 결제하면 자동으로 결제완료로 안넘어감...      1
# ...                                                   ...    ...
# 137825                                                ...      1
# 138275                                               None      1
# 138276                                               None      1
# 138277                                               None      1
# 138278                                               None      1
#
# [23901 rows x 2 columns]

# %%
best= df[:][df['score']==5] # score 값이 1점인 리뷰만 추출
best
# Out:
#                                                   content  score
# 4       1. 건의사항을 남기려고 보니 1:1실시간채팅/메일/전화상담뿐이더라고요. 따로 건의...      5
# 7       함께주문 기능을 다시 살려주세요. 당초 기능의 취지가 배달료 절약이었을지 몰라도.....      5
# 12      정말 잘 사용하고 있습니다! 결제 카드를 등록하려고 보니 본인것만 가능 하다고 하는...      5
# 16      요즘 잘 사용하고 있습니다! 다만 아쉬운 점은 각 음식 메뉴별 리뷰를 볼 수 없다는...      5
# 18      이용업체가 다른앱에 비교해서 약간 부족? 한것 같아요 추가글: 시간이 지날수록 조금...      5
# ...                                                   ...    ...
# 138268                                               None      5
# 138269                                               None      5
# 138270                                               None      5
# 138271                                               None      5
# 138272                                               None      5
#
# [146940 rows x 2 columns]

# %%
worst_all= df[:] [(df['score']==1) | (df['score']==2)]
worst_all
# Out:
#                                                   content  score
# 0       배민만 쓰다가 이번에 와우 결제해서 1만원 쿠폰 줬길래 처음 썼는데 진짜 불편함. ...      1
# 1       앱자체의 내비게이션이 말도 못하게 불편하다. 정북방향고정도 안되고 주행방향 화살표 ...      1
# 2       1. 배민처럼 한 그릇 배달이 나온 건 좋은데, 클릭하기 전에는 저렴한 가격으로 적...      2
# 3       하... 기분좋게 밥먹을려고했는데 진짜 너무 아쉽고 도착했다는 알람음에 기분좋게나갔...      1
# 6       배달현황 알림 말고 다른 알림을 끄는 기능이 없음. 음식 맛있었냐는 알림은 배달현황...      1
# ...                                                   ...    ...
# 137825                                                ...      1
# 138275                                               None      1
# 138276                                               None      1
# 138277                                               None      1
# 138278                                               None      1
#
# [26927 rows x 2 columns]

# %%
# txt 파일로 저장
worst_all.to_csv('worst_all.txt', index=False, header=None, sep="\t")
best.to_csv('best.txt', index=False, header=None, sep="\t")

# %% [markdown]
# ## 2. 데이터 전처리

# %% [markdown]
# ### 1. 텍스트 불러오기

# %%
import pickle
from konlpy.tag import Okt
import urllib.request
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


# 별점 5점인 데이터에서 라벨 1 추가
df_best = pd.read_table('best.txt', names=['content','label'])
df_best['label']= 1
df_best
# Out:
#                                                   content  label
# 0       1. 건의사항을 남기려고 보니 1:1실시간채팅/메일/전화상담뿐이더라고요. 따로 건의...      1
# 1       함께주문 기능을 다시 살려주세요. 당초 기능의 취지가 배달료 절약이었을지 몰라도.....      1
# 2       정말 잘 사용하고 있습니다! 결제 카드를 등록하려고 보니 본인것만 가능 하다고 하는...      1
# 3       요즘 잘 사용하고 있습니다! 다만 아쉬운 점은 각 음식 메뉴별 리뷰를 볼 수 없다는...      1
# 4       이용업체가 다른앱에 비교해서 약간 부족? 한것 같아요 추가글: 시간이 지날수록 조금...      1
# ...                                                   ...    ...
# 146935                                                NaN      1
# 146936                                                NaN      1
# 146937                                                NaN      1
# 146938                                                NaN      1
# 146939                                                NaN      1
#
# [146940 rows x 2 columns]

# %%
# 별점 1점과 0점인 데이터에서 라벨 0 추가
df_worst = pd.read_table('worst_all.txt', names=['content','label'])
df_worst['label']=0
df_worst
# Out:
#                                                  content  label
# 0      배민만 쓰다가 이번에 와우 결제해서 1만원 쿠폰 줬길래 처음 썼는데 진짜 불편함. ...      0
# 1      앱자체의 내비게이션이 말도 못하게 불편하다. 정북방향고정도 안되고 주행방향 화살표 ...      0
# 2      1. 배민처럼 한 그릇 배달이 나온 건 좋은데, 클릭하기 전에는 저렴한 가격으로 적...      0
# 3      하... 기분좋게 밥먹을려고했는데 진짜 너무 아쉽고 도착했다는 알람음에 기분좋게나갔...      0
# 4      배달현황 알림 말고 다른 알림을 끄는 기능이 없음. 음식 맛있었냐는 알림은 배달현황...      0
# ...                                                  ...    ...
# 26922                                                ...      0
# 26923                                                NaN      0
# 26924                                                NaN      0
# 26925                                                NaN      0
# 26926                                                NaN      0
#
# [26927 rows x 2 columns]

# %% [markdown]
# ### 2. 각 라벨값이 유일한지 확인

# %%
print(df_best['content'].nunique(), df_best['label'].nunique())
print(df_worst['content'].nunique(), df_worst['label'].nunique())
# Out:
# 96264 1
# 26370 1

# %% [markdown]
# ### 3. 중복 제거

# %%
df_best.drop_duplicates(subset=['content'], inplace=True)
df_worst.drop_duplicates(subset=['content'], inplace=True)

print(len(df_best))
print(len(df_worst))
# Out:
# 96265
# 26371

# %% [markdown]
# ### 4. 결측치 제거

# %%
df_best_d = df_best.dropna()
print(len(df_best_d))

df_worst_d = df_worst.dropna()
print(len(df_worst_d))
# Out:
# 96264
# 26370

# %% [markdown]
# ### 5. 데이터 정규화

# %%
# 데이터 정규화
df_best_d['content'] = df_best_d['content'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
df_worst_d['content'] = df_worst_d['content'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")

# df_best_d['content'] = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]',"",df_best_d['content']) 에러로 replace 사용
# df_best_d['content'] 가 여러문자를 담고있어서 에러남
# Out:
# /tmp/ipython-input-427327527.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_best_d['content'] = df_best_d['content'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# /tmp/ipython-input-427327527.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_worst_d['content'] = df_worst_d['content'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")

# %% [markdown]
# ## 3. 명사추출, 동사추출
# ### https://limsw.tistory.com/72
# ### https://soyoung-new-challenge.tistory.com/31

# %%
df_worst_d['content'].to_csv('worst.txt' ,index=False, header=None, sep="\t")

# %%
df_best_d['content'].to_csv('new_best.txt' ,index=False, header=None, sep="\t")

# %%
# 정규화한 df_worst_d에서 txt 파일로 저장하여 동의어 찾기
# df_worst_d['content'].to_csv('worst.txt' ,index=False, header=None, sep="\t")

# 명사 추출
from konlpy.tag import Okt
from collections import Counter

okt = Okt()
f = open('worst.txt', 'r', encoding='utf-8')
sentences = f.read()

noun = okt.nouns(sentences)
counter = Counter(noun)

top_100_noun_list = counter.most_common(100)

for i in top_100_noun_list:
    print(i)


## 동사추출
# f = open('worst.txt', 'r', encoding='utf-8')
# sentences = f.read()

# okt = Okt()

# # 형태소 분석 (품사 태깅)
# pos_tags = okt.pos(sentences,stem=True)

# # 동사만 추출
# verbs = [word for word, pos in pos_tags if pos == 'Verb']
# counter = Counter(verbs)
# top_100_verbs_list = counter.most_common(100)
# for i in top_100_verbs_list:
#   print(i)
# Out:
# ('주문', 6624)
# ('배달', 6448)
# ('요기', 3989)
# ('쿠폰', 3578)
# ('취소', 3453)
# ('앱', 3076)
# ('할인', 2619)
# ('왜', 2280)
# ('어플', 2259)
# ('결제', 2244)
# ('고객', 2002)
# ('시간', 1797)
# ('전화', 1724)
# ('사용', 1635)
# ('배민', 1602)
# ('가게', 1422)
# ('기요', 1422)
# ('진짜', 1357)
# ('좀', 1350)
# ('이벤트', 1329)
# ('패스', 1324)
# ('뭐', 1307)
# ('센터', 1270)
# ('음식', 1170)
# ('안', 1164)
# ('그냥', 1159)
# ('계속', 1156)
# ('거', 1141)
# ('삭제', 1111)
# ('업체', 1088)
# ('다시', 1086)
# ('때', 1064)
# ('리뷰', 1041)
# ('광고', 1021)
# ('더', 999)
# ('인증', 950)
# ('돈', 923)
# ('것', 919)
# ('상담', 886)
# ('말', 879)
# ('가입', 863)
# ('사람', 843)
# ('함', 810)
# ('번', 806)
# ('음식점', 802)
# ('이용', 768)
# ('로그인', 765)
# ('확인', 761)
# ('이', 754)
# ('곳', 744)
# ('오류', 738)
# ('개', 734)
# ('업데이트', 721)
# ('서버', 698)
# ('하나', 691)
# ('접속', 681)
# ('서비스', 678)
# ('요', 663)
# ('등록', 654)
# ('매장', 650)
# ('다른', 649)
# ('연결', 636)
# ('비', 624)
# ('최악', 611)
# ('연락', 606)
# ('수수료', 600)
# ('문제', 594)
# ('점', 586)
# ('치킨', 582)
# ('카드', 581)
# ('임', 574)
# ('문의', 568)
# ('후', 564)
# ('생각', 555)
# ('내', 552)
# ('못', 550)
# ('집', 546)
# ('관리', 543)
# ('수', 543)
# ('바로', 535)
# ('쓰레기', 535)
# ('처음', 533)
# ('메뉴', 510)
# ('혜택', 510)
# ('번호', 502)
# ('환불', 486)
# ('정말', 476)
# ('무슨', 476)
# ('또', 473)
# ('회원', 471)
# ('별로', 465)
# ('민족', 462)
# ('계정', 453)
# ('스', 452)
# ('한번', 451)
# ('지금', 444)
# ('장난', 439)
# ('제', 438)
# ('때문', 432)
# ('적용', 432)

# %% [markdown]
# ## 4. 데이터증강
# ### https://fish-tank.tistory.com/95
# ### https://working-helen.tistory.com/50

# %%
import pandas as pd
import random
from konlpy.tag import Okt
import numpy as np

# 형태소 분석기
okt = Okt()

# 동의어 사전
# Word2Vec / fastText 같은 임베딩 기반으로 자동 생성하기
# 특정 단어를 발견하면 동의어 중 하나로 바꿔줌
synonym_dict = {
    "나쁘다": ["별로다", "형편없다", "불만족스럽다"],
    "느리다": ["답답하다", "굼뜨다","느지막하다","느직느직하다",'늦다'],
    "불편하다" : ['갑갑하다','거북하다','괴롭다'],
    "힘들다" : ['거칠다','고단하다','어렵다'],
    "짜증" : ['신경질','역정','역증'],
    "어이없다" : ['어처구니없다','기가막히다'],
    "비싸다" : ['값이높다','값비싸다'],
    "아쉽다": ['안타깝다','서운하다'],
    "최악" : ['가장나쁨'],
    "빡치다": ['화나다','열받는다'],
    "실망스럽다" : ['낙심하다','비관하다','상실하다'],
    "왜": ['어째서','어찌','어째'],
    "오류" : ['과실','실수'],
    "문제" : ['말썽거리','말썽'],
    "정말" : ['사실'],
    "기다리다" : ['고대하다','기대하다','거종하다'],
    "모르다" : ['미지하다','부지하다'],
    "사라지다" : ['날아가다'],
    "취소" : ['결렬','철회','무산']

}

# 동의어 치환
# 한 문장에서 n개의 단어를 동의어로 치환
def synonym_replacement(sentence, n=2):
    words = okt.morphs(sentence)
    new_words = words.copy() # 원본보존
    candidates = [w for w in words if w in synonym_dict] # 사전에 있는 단어만 후보로
    random.shuffle(candidates)

    for i in range(min(n, len(candidates))):
        word = candidates[i]
        synonym = random.choice(synonym_dict[word])
        new_words = [synonym if w == word else w for w in new_words]
    return ''.join(new_words)

# 랜덤삭제
# 확률 p로 각 단어를 랜덤삭제
def random_deletion(sentence, p=0.2):
    words = okt.morphs(sentence)
    if len(words) == 1:
        return sentence
    new_words = [w for w in words if random.uniform(0,1) > p]
    if len(new_words) == 0:
        return random.choice(words)
    return ''.join(new_words)

# EDA 함수
def eda(sentence, num_aug):
    augmented = []
    augmented.append(synonym_replacement(sentence))
    augmented.append(random_deletion(sentence))
    return augmented[:num_aug] # num_aug의 수만큼 잘라서 반환

# 데이터 증강
def augment_dataframe(df_worst, target_size):
    augmented_texts = []
    original_texts = df_worst['content'].tolist() # tolist() : 같은 위치에 있는 데이터끼리 묶어준다

    while len(original_texts) + len(augmented_texts) < target_size:
        sentence = random.choice(original_texts)  # 원본에서 랜덤 문장 선택
        augmented_sentences = eda(sentence, num_aug=2) # EDA 적용
        augmented_texts.extend(augmented_sentences) # 증강된 문장 추가, augmented_sentences 이것이 리스트여서 extend 사용

    # 필요한 개수만큼 자르기
    augmented_texts = augmented_texts[:target_size - len(original_texts)]

    # 원본 + 증강 데이터 합치기
    final_texts = original_texts + augmented_texts
    df_augmented = pd.DataFrame(final_texts, columns=['content'])
    return df_augmented

df_best_d_size = len(df_best_d)
df_worst_d_size = len(df_worst_d)

df_worst_d_augmented = augment_dataframe(df_worst_d, df_best_d_size)

### 확인
print("원본 worst 데이터 개수:", df_worst_d_size)
print("증강 후 worst 데이터 개수:", len(df_worst_d_augmented))
# Out:
# 원본 worst 데이터 개수: 26370
# 증강 후 worst 데이터 개수: 96264

# %%
## 라벨링
df_worst_d_augmented['label']=0
# df_worst_d_augmented.columns=['content','label']
df_worst_d_augmented
# Out:
#                                                  content  label
# 0      배민만 쓰다가 이번에 와우 결제해서 1만원 쿠폰 줬길래 처음 썼는데 진짜 불편함. ...      0
# 1      앱자체의 내비게이션이 말도 못하게 불편하다. 정북방향고정도 안되고 주행방향 화살표 ...      0
# 2      1. 배민처럼 한 그릇 배달이 나온 건 좋은데, 클릭하기 전에는 저렴한 가격으로 적...      0
# 3      하... 기분좋게 밥먹을려고했는데 진짜 너무 아쉽고 도착했다는 알람음에 기분좋게나갔...      0
# 4      배달현황 알림 말고 다른 알림을 끄는 기능이 없음. 음식 맛있었냐는 알림은 배달현황...      0
# ...                                                  ...    ...
# 96259                                    잘가요.기요..아ㅋㅋㅋㅋㅋㅋ      0
# 96260                            어째자기들이잘못해놓고무책임한발언들을하는걸까      0
# 96261                               왜자기들이잘못해놓고무책임한들을하는걸까      0
# 96262  가장나쁨입니다햄버거주문후한시간이되도안오길래확인해보니주문누락롯데리아전화해보니요기요에서...      0
# 96263  최악입니다주문후한시간이되도안오길래확인주문누락해보니요기요에서주문이안옴썩을넘들돈빼갈는1...      0
#
# [96264 rows x 2 columns]

# %%
df_worst_d_augmented.to_csv('worst_aug.txt', index=False, header=None, sep="\t")

# %% [markdown]
# ## 5. 긍정어와 부정어 워드클라우드
# ### https://coding-yesung.tistory.com/201
# ### https://chongmin-k.tistory.com/entry/%EC%9B%8C%EB%93%9C%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C-%EC%98%A4%EB%A5%98-cannot-open-resource

# %%
### 주피터 노트북에서 실행
# !pip install wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

font_path =  'C:/Users/HJO/Desktop/python/malgun.ttf' #'C:/Windows/Fonts/malgun.ttf'

text = open('worst_aug.txt', encoding='utf-8').read()

# font_path 매개변수에 한글 폰트 경로 지정
wordcloud = WordCloud(
    font_path=font_path,
    width=800,
    height=800,
    background_color='white',
    stopwords= #불용어 지정 변수).generate(text)
).generate(text)

plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-2541794094.py in <cell line: 0>()
#      12     height=800,
#      13     background_color='white'
# ---> 14 ).generate(text)
#      15
#      16 plt.figure(figsize=(10, 10))
#
# /usr/local/lib/python3.12/dist-packages/wordcloud/wordcloud.py in generate(self, text)
#     640         self
#     641         """
# --> 642         return self.generate_from_text(text)
#     643
#     644     def _check_generated(self):
#
# /usr/local/lib/python3.12/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     622         """
#     623         words = self.process_text(text)
# --> 624         self.generate_from_frequencies(words)
#     625         return self
#     626
#
# /usr/local/lib/python3.12/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     451                 font_size = self.height
#     452             else:
# --> 453                 self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                                max_font_size=self.height)
#     455                 # find font sizes
#
# /usr/local/lib/python3.12/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     504                     break
#     505                 # try to find a position
# --> 506                 font = ImageFont.truetype(self.font_path, font_size)
#     507                 # transpose font optionally
#     508                 transposed_font = ImageFont.TransposedFont(
#
# /usr/local/lib/python3.12/dist-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     878
#     879     try:
# --> 880         return freetype(font)
#     881     except OSError:
#     882         if not is_path(font):
#
# /usr/local/lib/python3.12/dist-packages/PIL/ImageFont.py in freetype(font)
#     875
#     876     def freetype(font: StrOrBytesPath | BinaryIO) -> FreeTypeFont:
# --> 877         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     878
#     879     try:
#
# /usr/local/lib/python3.12/dist-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     283                         load_from_bytes(f)
#     284                     return
# --> 285             self.font = core.getfont(
#     286                 font, size, index, encoding, layout_engine=layout_engine
#     287             )
#
# OSError: cannot open resource

# %% [markdown]
# ### 6. 훈련데이터 , 테스트 데이터 split

# %%
from sklearn.model_selection import train_test_split
train_data_b, test_data_b = train_test_split(df_best_d, test_size=0.3, random_state=123)

print("Train data size:", len(train_data_b))
print("Test data size:", len(test_data_b))
# Out:
# Train data size: 67384
# Test data size: 28880

# %%
train_data_w, test_data_w = train_test_split(df_worst_d_augmented, test_size=0.3, random_state=123)

print("Train data size:", len(train_data_w))
print("Test data size:", len(test_data_w))
# Out:
# Train data size: 67384
# Test data size: 28880

# %%
# train 데이터끼리 묶기
train_data = pd.concat([train_data_b, train_data_w])
train_data
# Out:
#                                                   content  label
# 6335                          쿠팡와우 회원이라면 기꺼이 사용하는 게 편합니다.      1
# 4360                           넘 맛있어서 자주시켰먹구요 동생들오면 시켜줌니다      1
# 39555                                                  체거      1
# 6967                                배달도 빠르고 떡볶이 도 많이 주셨네요      1
# 133654                                             대박임..ㅋ      1
# ...                                                   ...    ...
# 63206   바베큐주문.1시간정도지났는데연락도없어서앱확인하니배송완료로나옴.배고파죽겠다.진짜.서비...      0
# 61404                           접속은힘들고로그인은아예안되서우째시키무란말입니까      0
# 17730                                       들어가지지도 않는 쓰레기      0
# 28030   배달비가표기된가격보다비쌉니다.자세히보기를눌러야만실제지불가격이나와요.어플초기엔안그랬는...      0
# 15725   요기오에서 할인하는 가게 배민은 오픈해도 요기오는 안받더라구요 요기오측에서 조치를 ...      0
#
# [134768 rows x 2 columns]

# %%
# test 데이터끼리 묶기
test_data = pd.concat([test_data_b, test_data_w])
test_data
# Out:
#                                                   content  label
# 52726                         너무 좋아요.. 다 좋은데 업체가 조금 부족하네요      1
# 123965                  진짜편리해요!! 전화하는것보다 폰으로 알아서 주문착착굿굿!!      1
# 133252  배달 오는 시간 까지 알려주는 신개념 앱!!! 그리고 전화통화를 하지 않아서 편해요!!!      1
# 49621   다른 배달앱보다 혜택도 많고 고객을 위한다는 느낌을 많이 받고 있네요 진작에 요기요...      1
# 66293                              전에 쓰던거보다 인간적으로 더 좋습니다.      1
# ...                                                   ...    ...
# 31480                                               설치가안됨      0
# 61409   10+사용자인데주내장바구니담고장바구니로어플이멈추는데지금까지몇번을했는데수정이안되네요열쓰겠음      0
# 42623                    뭐치킨집사정어고하면서주문취소됫는데왜돈안돌려주나요?폰결제는데      0
# 79790   솔직히시켜먹으려는가게10개중에7개는등록안되어있고해달라고계속신청해도안되고오로지요기패쓰...      0
# 14995           포장주문해서 배달비 좀 아끼고 싶었는데 그런 기능이 없어서 불만족스러워요ㅠ      0
#
# [57760 rows x 2 columns]

# %%
print(test_data['content'].nunique(), test_data['label'].nunique())
print(train_data['content'].nunique(), train_data['label'].nunique())
# Out:
# 55298 2
# 124342 2

# %%
train_data['label'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='label'>

# %% [markdown]
# ### 8. 토큰화

# %%
import pickle
import pandas as pd
import numpy as np
import re
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


# 불용어 지정
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자',
             '에','와','한','하다']

# okt를 활용한 형테소 분석
okt = Okt()
x_train = []
for sentence in train_data['content']:
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    x_train.append(stopwords_removed_sentence)

print(x_train[:2])
# Out:
# [['쿠팡', '와우', '회원', '라면', '기꺼이', '사용', '게', '편하다', '.'], ['넘다', '맛있다', '자주', '시키다', '먹다', '동생', '오다', '시키다', '주다']]

# %%
x_test = []
for sentence in test_data['content']:
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    x_test.append(stopwords_removed_sentence)

print(x_test[:2])
# Out:
# [['너무', '좋다', '..', '다', '좋다', '업체', '조금', '부족하다'], ['진짜', '편리하다', '!!', '전화하다', '폰', '알다', '주문', '착착', '굿굿', '!!']]

# %% [markdown]
# ### 9. 정수 인코딩 : 훈련 데이터에 대해 단어집합(vacaburary) 만듦

# %%
## 단어에 숫자지정
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_train)

print(tokenizer.word_index)
# Out:
# {'.': 1, '배달': 2, '좋다': 3, '요': 4, '주문': 5, '되다': 6, '을': 7, '없다': 8, '있다': 9, '?': 10, '앱': 11, '할인': 12, '요기': 13, '쿠폰': 14, '안되다': 15, '시키다': 16, '보다': 17, '로': 18, '..': 19, '하': 20, '먹다': 21, '받다': 22, '어플': 23, '안': 24, '같다': 25, '편하다': 26, '만': 27, '쿠팡': 28, '쓰다': 29, '너무': 30, '결제': 31, '하고': 32, '많다': 33, ',': 34, '사용': 35, '아니다': 36, '에서': 37, '다': 38, '...': 39, '음식': 40, '이다': 41, '않다': 42, '배민': 43, '고객': 44, '못': 45, '시간': 46, '~': 47, '주': 48, '!': 49, '해주다': 50, '이벤트': 51, '문': 52, '취소': 53, '때': 54, '다른': 55, '전화': 56, '오다': 57, '빠르다': 58, '기요': 59, '고': 60, '진짜': 61, '이용': 62, '편리하다': 63, '자다': 64, '츠': 65, '뜨다': 66, '리뷰': 67, '더': 68, '많이': 69, '가게': 70, '센터': 71, '알다': 72, '그냥': 73, '네': 74, '돼다': 75, '중': 76, '주다': 77, '왜': 78, '면': 79, '거': 80, '그렇다': 81, '것': 82, '나': 83, '^^': 84, '기': 85, '서': 86, '써다': 87, '정말': 88, '계속': 89, '뭐': 90, '업체': 91, '까지': 92, '되어다': 93, '첫': 94, '가다': 95, '무료': 96, '삭제': 97, '사람': 98, '적': 99, '비': 100, '전화하다': 101, '게': 102, '내': 103, '패스': 104, '곳': 105, '자주': 106, '모르다': 107, '음식점': 108, 'ㅋㅋ': 109, '지': 110, '광고': 111, '메뉴': 112, '원': 113, '혜택': 114, '들다': 115, '집': 116, '수': 117, '!!': 118, '최고': 119, '그': 120, '쓸다': 121, '넘다': 122, '점': 123, '서비스': 124, '나오다': 125, '인데': 126, '1': 127, '인': 128, '제': 129, '개': 130, '바로': 131, '번': 132, '매장': 133, '말': 134, '확인': 135, '이나': 136, '간편하다': 137, '돈': 138, '들어가다': 139, '생각': 140, 'ㅎㅎ': 141, '만들다': 142, '처음': 143, '상담': 144, '맛있다': 145, '깔다': 146, '불편하다': 147, '용하다': 148, '함': 149, '별': 150, '다시': 151, '저': 152, 'ㅡㅡ': 153, '가입': 154, '이렇다': 155, '등록': 156, '니': 157, '카드': 158, '인증': 159, '기사': 160, '기다리다': 161, '치킨': 162, '말다': 163, '1시간': 164, '니까': 165, '~~': 166, '해보다': 167, '업데이트': 168, '건지다': 169, '라고': 170, '배송': 171, '회원': 172, '한번': 173, '시': 174, '늘다': 175, '임': 176, '이라': 177, '가능하다': 178, '라': 179, '맛': 180, '로그인': 181, '보고': 182, '버리다': 183, '누르다': 184, '쉬다': 185, '아주': 186, '아': 187, '연락': 188, '님': 189, '짱': 190, '찾다': 191, '연결': 192, '가격': 193, '이네': 194, '??': 195, '수수료': 196, '두': 197, 'ㅋㅋㅋ': 198, '일': 199, '앞': 200, '쓰레기': 201, '무슨': 202, '그리고': 203, 'ㅋ': 204, '굿': 205, '이런': 206, '민족': 207, '없이': 208, '항상': 209, '료': 210, '비싸다': 211, '짜증나다': 212, '도안': 213, '때문': 214, '또': 215, '30분': 216, '전': 217, '차다': 218, '해': 219, '별로': 220, '후': 221, '시스템': 222, '걸리다': 223, '포인트': 224, '하나': 225, '관리': 226, '다양하다': 227, '지우다': 228, '서버': 229, '부터': 230, 'ㅎ': 231, '어떻다': 232, '마다': 233, '2': 234, '이랑': 235, '라이더': 236, '접속': 237, '분': 238, '타': 239, '....': 240, '문의': 241, '에는': 242, '늦다': 243, '환불': 244, '빨리': 245, '감사하다': 246, '여기': 247, '소비자': 248, '완전': 249, '최악': 250, '위치': 251, '번호': 252, '나다': 253, '오늘': 254, '나쁘다': 255, '잇다': 256, '아깝다': 257, '어': 258, '검색': 259, '이제': 260, '오류': 261, '완료': 262, '잘못': 263, '직접': 264, '선택': 265, '주소': 266, '기분': 267, '해도': 268, '적다': 269, '이라고': 270, '싶다': 271, '금액': 272, '자꾸': 273, '지금': 274, '문제': 275, '와우': 276, '사': 277, '랑': 278, '가장': 279, '추천': 280, '요즘': 281, '한테': 282, '지역': 283, '다시다': 284, '라는': 285, '요가': 286, '여': 287, '문자': 288, '싸다': 289, '설치': 290, '탈퇴': 291, '이유': 292, '개선': 293, ')': 294, '이상': 295, '!!!': 296, '이고': 297, '처리': 298, '째': 299, '비다': 300, '몇': 301, '죠': 302, '적용': 303, '치다': 304, '서다': 305, '다르다': 306, '잘쓰다': 307, '야하다': 308, '걸': 309, '기능': 310, '자체': 311, '철회': 312, '(': 313, '정도': 314, '엔': 315, '에서는': 316, '요청': 317, '뭔': 318, '3': 319, '듯': 320, '경우': 321, '중복': 322, '데': 323, '배': 324, '이렇게': 325, '유용하다': 326, '결국': 327, '스': 328, '갈아타다': 329, '계정': 330, '정보': 331, '에게': 332, '본인': 333, '해결': 334, '무산': 335, '맞다': 336, '다운': 337, '결렬': 338, '~^^': 339, '익스': 340, '프레': 341, '대': 342, '접수': 343, '추가': 344, '저렴하다': 345, '보내다': 346, '사장': 347, '놓다': 348, '엄청': 349, '애용': 350, '바꾸다': 351, '건': 352, '보기': 353, '맛집': 354, '적립': 355, '지다': 356, '인지': 357, '끄다': 358, '장난': 359, '제대로': 360, '알림': 361, '결재': 362, 'ㅠㅠ': 363, '알': 364, ';;': 365, '느리다': 366, '갑자기': 367, '기업': 368, '사진': 369, '간': 370, '여러': 371, '포장': 372, '설정': 373, '식': 374, '어찌':  ...

# %%
word_size = len(tokenizer.word_index)
print('word_size : ', word_size)
# Out:
# word_size :  37820

# %% [markdown]
# ### 12. 텍스트 시퀀스를 정수 시퀀스로 변환

# %%
# tokenizer = Tokenizer(vocab_size)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_train)
x_train = tokenizer.texts_to_sequences(x_train)
x_test = tokenizer.texts_to_sequences(x_test)

print(x_train[:3])
# Out:
# [[28, 276, 172, 995, 20205, 35, 102, 26, 1], [122, 145, 106, 16, 21, 2394, 57, 16, 77], [20206]]

# %%
y_train = np.array(train_data['label'])
y_test = np.array(test_data['label'])

# %%
# X_train = np.delete(X_train, drop_train, axis=0. dtype=object)
# X_train = np.delete(x_train, drop_train, axis=0)
# y_train = np.delete(y_train, drop_train, axis=0)
print(len(x_train))
print(len(y_train))
# Out:
# 134768
# 134768

# %% [markdown]
# ### 14. 패딩 : 서로 다른 길이의 샘플들의 길이를 동일하게 맞춰주는 패딩 작업을 진행

# %%
# 단어 인덱스로 바꾼 뒤 길이가 다 다르기 때문에 모두 동일한 길이로 맞춰줘야 함
# y_train은 단일값(0,1)로 이루어져 있어서 패딩 안해도 됨
x_train = pad_sequences(x_train, maxlen=100) # maxlen : 문장의 길이를 보고 결정
x_test = pad_sequences(x_test, maxlen=100)

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

# %% [markdown]
# ## 3. 감정분석 모델링
# ### https://dev-with-gpt.tistory.com/55

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

embedding_dim = 100
hidden_units = 128

model = Sequential()
model.add(Embedding(word_size+1, embedding_dim)) # word_size: 37820, 임베딩과정
model.add(LSTM(hidden_units))
model.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.fit(x_train, y_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/15
# 1685/1685 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - acc: 0.8816 - loss: 0.2814
# Epoch 1: val_acc improved from -inf to 0.93118, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1685/1685 ━━━━━━━━━━━━━━━━━━━━ 391s 230ms/step - acc: 0.8816 - loss: 0.2813 - val_acc: 0.9312 - val_loss: 0.1890
# Epoch 2/15
# 1685/1685 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - acc: 0.9419 - loss: 0.1639
# Epoch 2: val_acc did not improve from 0.93118
# 1685/1685 ━━━━━━━━━━━━━━━━━━━━ 443s 231ms/step - acc: 0.9419 - loss: 0.1639 - val_acc: 0.9238 - val_loss: 0.2120
# Epoch 3/15
# 1685/1685 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - acc: 0.9493 - loss: 0.1467
# Epoch 3: val_acc did not improve from 0.93118
# 1685/1685 ━━━━━━━━━━━━━━━━━━━━ 442s 231ms/step - acc: 0.9493 - loss: 0.1467 - val_acc: 0.9302 - val_loss: 0.1956
# Epoch 4/15
# 1685/1685 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - acc: 0.9538 - loss: 0.1336
# Epoch 4: val_acc did not improve from 0.93118
# 1685/1685 ━━━━━━━━━━━━━━━━━━━━ 443s 231ms/step - acc: 0.9538 - loss: 0.1336 - val_acc: 0.9287 - val_loss: 0.2003
# Epoch 5/15
# 1685/1685 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - acc: 0.9583 - loss: 0.1216
# Epoch 5: val_acc did not improve from 0.93118
# 1685/1685 ━━━━━━━━━━━━━━━━━━━━ 432s 225ms/step - acc: 0.9583 - loss: 0.1216 - val_acc: 0.9245 - val_loss: 0.2077
# Epoch 5: early stopping

# %% [markdown]
# ### 1. 훈련 과정에서 검증 데이터의 정확도가 가장 높았을 때 저장된 모델인 'best_model.h5'를 로드

# %%
loaded_model = load_model('best_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(x_test, y_test)[1]))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1805/1805 ━━━━━━━━━━━━━━━━━━━━ 85s 47ms/step - acc: 0.9361 - loss: 0.1820
#
#  테스트 정확도: 0.9337

# %%
def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = 100) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %%
sentiment_predict('너무 불편해요. 지역을 입력하고 주변 매장을 확인할 때 목록으로만 확인해야해서 매장 선택해서 가게 위치 하나하나 확인했네요. 다른 어플처럼 목록으로뿐 아니라 지도상으로도 주변 매장 위치들이 한눈에 보이면 좋을텐데요')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 52.96% 확률로 긍정 리뷰입니다.
# /tmp/ipython-input-173600839.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   score = float(loaded_model.predict(pad_new)) # 예측

# %% [markdown]
# ### 2. 모델저장

# %%
with open('tokenizer.pickle', 'wb') as handle:
     pickle.dump(tokenizer, handle)

#with open('tokenizer.pickle', 'rb') as handle:
#    tokenizer = pickle.load(handle)

# %% [markdown]
# ### 3. 예측하기 : 임의의 리뷰에 대해서 예측하는 함수

# %%
def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %%
sentiment_predict('너무 불편해요. 지역을 입력하고 주변 매장을 확인할 때 목록으로만 확인해야해서 매장 선택해서 가게 위치 하나하나 확인했네요. 다른 어플처럼 목록으로뿐 아니라 지도상으로도 주변 매장 위치들이 한눈에 보이면 좋을텐데요')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 52.96% 확률로 긍정 리뷰입니다.
# /tmp/ipython-input-173600839.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   score = float(loaded_model.predict(pad_new)) # 예측

# %%
sentiment_predict('위메프가 뭘 하겟냐만은. 설치도 안돼는 꼬락서니하곤.배송늦고 쓰레기만팔고 환불도 안해줘 진작 끊엇는데 배달도 그렇겟지 쓰레기로 갖다주고 늦게 오겟지.애국심에 설치하렷더만.ㅉ모든프로그램개발사를 제대로 선정못하네.비리가 잇것지.인터넷장사하는데 프로그램이 이상해서야.')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 99.45% 확률로 부정 리뷰입니다.
# /tmp/ipython-input-173600839.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   score = float(loaded_model.predict(pad_new)) # 예측

# %%
sentiment_predict('생각보다 너무 깔끔하고 보기 편하게 되어있어서 쓰기 편하고 공공배달서비스라서 쓰고 있습니당')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 99.44% 확률로 긍정 리뷰입니다.
# /tmp/ipython-input-173600839.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   score = float(loaded_model.predict(pad_new)) # 예측
